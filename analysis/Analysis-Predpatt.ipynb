# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_colwidth', 1000)
pd.set_option('display.max_rows', 2000)

from predpatt import PredPatt
from predpatt import load_conllu
from predpatt import PredPattOpts

# %%
somedata = pd.read_csv('corpus_some-master/data/some_database.csv', sep='\t')
somedata.head()
# Out:
#         Item  workerid  Rating Partitive  StrengthSome Mention Subjecthood  \
# 0  176651:43        22       5       yes           5.7     new       other
# 1  176651:43        25       4       yes           5.7     new       other
# 2  176651:43        33       7       yes           5.7     new       other
# 3  176651:43         9       3       yes           5.7     new       other
# 4  176651:43        18       7       yes           5.7     new       other
#
#   Modification  \
# 0     modified
# 1     modified
# 2     modified
# 3     modified
# 4     modified
#
#                                                                       Sentence  \
# 0  a, a contractor friend helped me, uh, with some of the, uh, foundation work
# 1  a, a contractor friend helped me, uh, with some of the, uh, foundation work
# 2  a, a contractor friend helped me, uh, with some of the, uh, foundation work
# 3  a, a contractor friend helped me, uh, with some of the, uh, foundation work
# 4  a, a contractor friend helped me, uh, with some of the, uh, foundation work
#
#    SentenceLength  Trial
# 0              14      1
# 1              14      1
# 2              14      1
# 3              14      1
# 4              14      1

# %%
uniq = somedata[['Item', 'Sentence']].drop_duplicates('Item')
uniq = uniq.set_index('Item')
print(uniq.shape)
# Out:
# (1362, 1)

# %%
import stanza
from stanza.utils.conll import CoNLL

document = '\n\n'.join(uniq['Sentence'].tolist()) 
nlp = stanza.Pipeline(lang='en', tokenize_no_ssplit=True)
doc = nlp(document)
dic = doc.to_dict()
conllu = CoNLL.convert_dict(dic)

with open('corpus_some-master/allsents.conllu', 'w') as f:
    for sent in conllu:
        for word in sent:
            txt = "\t".join(word) + "\n"
            f.write(txt)
        f.write("\n")
# Out:
# 2020-07-20 15:31:40 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | ewt       |
# | pos       | ewt       |
# | lemma     | ewt       |
# | depparse  | ewt       |
# | ner       | ontonotes |
# =========================
#
# 2020-07-20 15:31:40 INFO: Use device: cpu
# 2020-07-20 15:31:40 INFO: Loading: tokenize
# 2020-07-20 15:31:40 INFO: Loading: pos
# 2020-07-20 15:31:41 INFO: Loading: lemma
# 2020-07-20 15:31:41 INFO: Loading: depparse
# 2020-07-20 15:31:42 INFO: Loading: ner
# 2020-07-20 15:31:43 INFO: Done loading processors!

# %%
options = PredPattOpts(resolve_relcl=True, borrow_arg_for_relcl=True, resolve_conj=False, cut=True)
with open('corpus_some-master/allsents.conllu', 'r') as f:
    data = f.read()
    parsed = [PredPatt(ud_parse, opts=options) for sent_id, ud_parse in load_conllu(data)]

# %%
from collections import Counter
deprels = []
nps = []
for sent in parsed:
    someind = [a.text.lower() for a in sent.tokens].index('some')
    if not sent.tokens[someind].dependents:
        np = [a.gov.text for a in sent.tokens[someind].gov.dependents if (a.dep.text.lower()=='some' 
                                                                      and 
                                                                      a.rel in ['det', 'obj', 'nsubj', 
                                                                                'nmod', 'conj'])] 
#         nps = [a.rel for a in sent.tokens[someind].gov.dependents if a.dep.text.lower()=='some']
#         deprels += [a.rel for a in sent.tokens[someind].gov.dependents if a.dep.text.lower()=='some']
    else:
        np = [a.dep.text for a in sent.tokens[someind].dependents if a.rel in ['nsubj','nmod', 'conj']] 
#     deprels += [a.rel for a in sent.tokens[someind].dependents]
    nps.append(' '.join(np))

# %%
uniq['NP'] = nps

# %%
somedata['NP'] = somedata['Item'].apply(lambda x: uniq.loc[x, 'NP'])

# %%
# somedata.to_csv('corpus_some-master/somedata_nps.tsv', sep="\t", index=False)

# %%
# Simple way to figure out if its countable or not
# uniq['Count'] = uniq['NP'].apply(lambda x: x[-1]=='s' if x else False)
# uniq.to_csv('corpus_some-master/somedata_npscount.tsv', sep="\t")

# %%
# For now ignore all the words which are more than one word long
uniq['len'] = uniq['NP'].apply(lambda x: len(x.split()))
uniq = uniq[uniq['len']==1]


lemmatizer = stanza.Pipeline(lang='en', processors='tokenize,mwt,pos,lemma')

uniq['lemma'] = uniq['NP'].apply(lambda x: lemmatizer(x).sentences[0].words[0].lemma)
# Out:
# 2020-07-20 15:34:16 WARNING: Can not find mwt: default from official model list. Ignoring it.
# 2020-07-20 15:34:16 INFO: Loading these models for language: en (English):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | ewt     |
# | pos       | ewt     |
# | lemma     | ewt     |
# =======================
#
# 2020-07-20 15:34:16 INFO: Use device: cpu
# 2020-07-20 15:34:16 INFO: Loading: tokenize
# 2020-07-20 15:34:16 INFO: Loading: pos
# 2020-07-20 15:34:17 INFO: Loading: lemma
# 2020-07-20 15:34:17 INFO: Done loading processors!

# %%
celex = pd.read_csv('corpus_some-master/celex.csv')
celex=celex.set_index('Noun')

def count_mass(col, word):
    if word in celex.index:
        return celex.loc[word, col]
    else:
        return 'NF'

# %%
uniq['Count'] = uniq['lemma'].apply(lambda x: count_mass(col='Celex Countable', word=x))
uniq['Mass'] = uniq['lemma'].apply(lambda x: count_mass(col='Celex Uncountable', word=x))

# %%
uniq
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                             Sentence  \
# Item
# 176651:43                                                                                                                                                                                                                                                                                                                                                a, a contractor friend helped me, uh, with some of the, uh, foundation work
# 108182:30                                                                                                                                                                                                                                                                                                                                                               i guess you have  to take some things and leave some things.
# 20718:26                                                                                                                                                                                                                                                                                                                                 well, i know that we have some relatives that  live around, like the mumblex area in there,
# 18335:127                                                                                                                                                                                                                                                                  just if you want a lot of, you know, light for underneath, that may be the, all right because we had, because we have some, we have some old fruit trees.
# 88808:43                                                                                                                                                                                                                                                                                                                                although, um, i have also done oh, free lance magazine writing and some educational writing.
# 148561:14                                                                                                                                                                                                                                                                                                                                                                                                  i mean, some people sing,
# 176908:22                                                                                                                                                                                                                                                                                                                                                            and you say you have some strong feelings about, uh, the issue.
# 34501:47                                                                                                                                                                                                                                                                                                        but it was on a higher level, you know, where there were some things that kids didn't understand  that adults did  ,
# 1686:32                                                                                                                                                                                                                                                                                                                                                                      and, uh, quite honestly, i, i have some little children
# 9196:49                                                                                                                                                                                                                                                                                                                      but i do think that, um, congress has backed down much too much on some of the air pollution standards.
# 24580:124                                                                                                                                                                                                                                                               and, and it's and it's based  on, on a perception that someone has  as how a drug user would behave  when some drug users behave, uh, normal , uh, you know.
# 68658:113                                                                                                                                                                                                                                                                          but, if there are some people who  don't agree uh, then there must be, it seems  to be there must be at least a reasonable doubt for some people.
# 16209:29                                                                                                                                                                                                                                                                                                                                                                       and i have two different kinds of breads and some ham
# 112844:32                                                                                                                                                                                                                                                                                                                                        i have worked in anoth-, at some other ones that  were not very good in my opinion.
# 89238:15                                                                                                                                                                                                                                                                                                                                                                                  and she was wanting some more information.
# 112290:7                                                                                                                                                                                                                                                                                                                                                                                                           and some of those
# 145433:59                                                                                                                                                                                                                                                                                                                                                    even with my gas card you know, i find that i'll go in  to get some gas
# 77398:5                                                                                                                                                                                                                                                                                     some of the people that i work with  they, like when i worked on second shift , um, their paren-, their kids go to school during the day
# 102781:19                                                                                                                                                                                                                                                                                                                                                                            i went to dinner with some friends last weekend
# 80692:12                                                                                                                                                                                                                                                                                                                                                                               and you get some beautiful effects with them.
# 4490:19                                                                                                                                                                                                                                                                                                                                 um, there's been some progressive medical schools  out here, that  have taken that approach.
# 176346:41                                                                                                                                                                                                                                                                                                                                               he crashed and killed some people because he was, uh, smoking some marijuana
# 163367:85                                                                                                                                                                                                                                                     but i think it's got a little more relevance since they are around dangerous equipment and things like that and do have  to exercise some quick judgment in the field.
# 134426:32                                                                                                                                                                                                                                                                                                            and, uh, we've got some plum trees and some apple trees and some tomato and some blackberries and strawberries.
# 53223:87                                                                                                                                                                                                                                                                                                                          i, uh, i left t i in january  hoping  to strike out and find a job where i could make some money .
# 36420:35                                                                                                                                                                                                                                                                                                                                                            we've, uh, just save the fees and buy some of our own equipment.
# 95199:151                                                                                                                                                                                                          but when time came  to direct their ability to make choices to develop the kinds of things that, that they're going  to need   to interact with other people  , i felt like i needed some strong influence there.
# 114255:29                                                                                                                                                                                                                                                                                                                                                                                     um, uh, i think there's some problems,
# 140052:14                                                                                                                                                                                                                                                                                                                                                                                              but my son needed some money,
# 155121:37                                                                                                                                                                                                                                                                                                                  uh, a colleague of mine at, uh, work got some information over, uh, the computer network called internet.
# 56319:15                                                                                                                                                                                                                                                                                                                                                                              and i shred up some just regular white cheese.
# 120254:15                                                                                                                                                                                                                                                                                                                                                   i've read some things about him that he was, he wasn't too good himself.
# 99947:44                                                                                                                                                                                                                                                                                                                                                               so but, uh, you know, we probably did some ice skating on it,
# 103563:4                                                                                                                                                                                                                                                                                                                 some people are really afraid to recycle the fuel because they're afraid it could become, uh, bomb quality.
# 35674:45                                                                                                                                                                                                                                                   and so she's going  to get some money for that and take some money from the bank and then try  to make as much down payment as possible  to keep the monthly payment low.
# 140964:11                                                                                                                                                                                                                                                                                                                                                                                              and spend some time with him.
# 47593:18                                                                                                                                                                                                                                                                                                                                                                                         then my father got us some tickets,
# 54511:40                                                                                                                                                                                                                                                                                                                                                                       there's, there is, you know some blood and everything
# 38844:23                                                                                                                                                                                                                                                                                                                                                                         i do do some crafts like it mentioned in the thing,
# 72387:13                                                                                                                                                                                                                                                                                                                           and i see some of the problems the kids have  when they don't have a real good family structure .
# 15535:31                                                                                                                                                                                                                                                                                                                                                                   now, i've seen, you know, some different clips of it, um,
# 91704:14                                                                                                                                                                                                                                                                           i'm doing some reviews of books,  just to, what, to sort of recommend to wh-, whether or not a full-scale review should be done  for the journal,
# 29385:35                                                                                                                                                                                                                                                                                                                                                           and they go back and forth, where everyone's giving some opinions
# 165513:41                                                                                                                                                                                                                                                                                                              and then with that i try and handle, you know, some of the clothes that the girls need  and things like that,
# 5156:27                                                                                                                                                                                                                                                                                                                                          i've been trying  to do some bibs for him. and, uh, work on his christmas stocking.
# 71923:26                                                                                                                                                                                                                                                                                                                                                                      because i work some weird hours and do some traveling.
# 1177:17                                                                                                                                                                                                                                                                                                                                                                                                  i've even had some of them,
# 109067:60                                                                                                                                                                                                                                                                                                                  marinated in olive oil and some seasoning, um, and cooked with some olives and some, and some prunes, uh,
# 8885:15                                                                                                                                                                                                                                                                                                                                                                              what  are some of your things you like  to do .
# 102431:45                                                                                                                                                                                                                    i know they do do some, they do have some classes   in, um, high schools and things for kids  to, uh, give them an idea of what family life is like  and the, uh, you know, and, uh, that kind of thing
# 57403:47                                                                                                                                                                                                                                                                                                                                         it had, uh, leather, leather designs and, um, some other, other little things on it
# 88674:10                                                                                                                                                                                                                                                                                                                                                                     i did some typing for my father when he had the company
# 96886:11                                                                                                                                                                                                                                                                                                                                                         there's some men out there that  are more feminine than most women.
# 9967:56                                                                                                                                                                                                                                                                                                                       they don't understand that to make that work, they've got  to take some responsibility for themselves.
# 97989:5                                                                                                                                                                                                                                                                                                                                              some of the changing roles of women in that respect, i have been a product of .
# 2345:39                                                                                                                                                                                                                                                            i, uh, have attended some seminars that  had some tapes that  went with them, but, uh, i guess not so much books although they sometimes have manuals and things,
# 113850:63                                                                                                                                                                                                                                        if they were  to take half of what they spend  on that and put it on some economic, you know, inter-, intergovernmental or inter united states like programs that one really might.
# 82800:12                                                                                                                                                                                                                                                                                                                    my wife did some teaching at like, uh, like a private tutoring place. a sylvan learning center this year
# 116717:11                                                                                                                                                                                                                                                                                                                                                                                    i know some people that  went to b y u.
# 20142:232                                                                                                                      well, i think in a way, though, uh, uh, i also have, uh, an opposite point of view, which  is, uh, although i believe we should, uh, permit, uh, you know, constant immigration into this country uh, i think we should, uh, primarily for economic reasons, i think we should have, um, some quotas,
# 171282:63                                                                                                                                                                                                                        but i guess, i guess i like the system that they have  in some places where the defendant gets  to choose whether he's, goes before a jury for sentencing or whether the judge gets  to choose it .
# 1939:10                                                                                                                                                                                                                                                                                          i saw some promise, you know, with, with a lot of the new wave, when it, when it came out, uh, back in the mid and early eighties .
# 11991:7                                                                                                                                                                                                                                                                                                                                                    and some of it runs off right away into the, in to the streams and rivers
# 134021:50                                                                                                                                                                              and i think that it's, it's very surprising some of these very expensive volvos can be gotten  for a lot less money than you would think if you're willing  to buy ones that  are about, the vintage of the cars that you and i currently own
# 15332:88                                                                                                                                                                                                                                                                                                            everybody i know  has been, well, i'm going  to go  get a goo-, good job and make some money and buy a nice car.
# 145355:18                                                                                                                                                                                                                                                                                                                                            uh, i got in some problems with, uh, financial problems because of credit cards
# 65999:146                                                                                                                                    but, uh, you know, i think, uh, they, maybe they need  to, uh, help  promote that more. give incentives like, uh, if they do bring somebody on, they will pay some of their costs or give tax breaks or whatever it is , you know, for them to train people, you know, stuff like that.
# 137619:16                                                                                                                                                                                                                                                                                                                                                                               but they're doing some stomping on virginia.
# 161653:6                                                                                                                                                                                                                                                                                                                                                             but some people are more motorboaters, you know which  is fine.
# 126165:57                                                                                                                                                                                                                                                                                                                                                          i've got where now i can hit it in, in the air some of the time .
# 148538:10                                                                                                                                                                                                                                                                                                                                                                                                i have some dulcimer music.
# 103624:72                                                                                                                                                                                                                                                                                                                              it's just, you know, a possible solution in the future, i think , maybe to help in some ways.
# 155962:19                                                                                                                                                                                                                                                                                                                        and i think also some of the, uh, car companies are coming out with, uh, gas powered fleets so you,
# 138291:103                                                                                                                                   i'd, i'd kind of like  to, to look at equipment like a lathe or like you say, a table saw and some of those things that  would make, uh, some pretty nice, uh, pieces of, uh, well, wood, for, for different things for tables, for, for, uh, chairs, for, you know, decks and so forth
# 7267:12                                                                                                                                                                                                                                                                                                                                                                                          and painting and some wallpapering,
# 112156:136                                                                                                                                                                                                                                                                            and, uh, you know, there was, there was, nothing on it, which  makes me wonder, you know, if it's as, uh, prevalent as, as some of them claim.
# 32005:38                                                                                                                                                                                                                                                                        and his, uh, son built him a garage and got him some, uh, oh, i don't know what the equipment's called  , but planers and things and s-, set him up,
# 107909:42                                                                                                                                                                                                                                                                                                                                                   and i don't know why we couldn't have duplicate voting on some of this .
# 78585:7                                                                                                                                                                                                                                                                                                                                                                   so some of the things are not as, quite as, uh, adaptable.
# 94633:27                                                                                                                                                                                                                                                                                                                        and it's a chance to see some of the relatives you don't see  all year long except that once a year.
# 164050:47                                                                                                                                                                                                                                                                                                                       but there's so many occasions when i've had  to move some members of the family or do this or that ,
# 65989:12                                                                                                                                                                                                                                                                                                                                                                                                so we had some interference,
# 109644:34                                                                                                                                                                                                                                                                                                                                                                      so, i guess we're old timers compared to some people.
# 35565:48                                                                                                                                                                                                                                                                                                          and, uh, if i consider  going the used car route and save up some money, i shouldn't have too much trouble at all.
# 47226:12                                                                                                                                                                                                                                                                                                and there's some pretty decent campgrounds although, i don't think raleigh, i don't think the state of north carolina takes,
# 98248:22                                                                                                                                                                                                                                                                                                                                                                     and i think there are some people that  have done that,
# 30428:73                                                                                                                                                                                                                                                                                                                                   then, you know, then, we thought, well we can use it for, you know, some personal things.
# 23510:57                                                                                                                                                                                                                                                                                                                                                       and let's, you know, let's get rid  of some of this harassment suing.
# 121569:26                                                                                                                                                                                                                                                                                                                                                                  i just wish they'd bring some of the old characters back.
# 172264:114                                                                                                                                                                                                                                                           i mean, obviously, i do most of my, almost all of my report writing on, on my computer, uh, whether it's term papers or even some smaller homework assignments.
# 161396:28                                                                                                                                                                                                                                                                                                                                                                              uh, and some of, some stuff that i like , uh,
# 5366:34                                                                                                                                                                                                                                                                                                                    uh, we had some, uh, some people from our church  went to israel, uh, just for a, uh, tour sort of thing.
# 12111:78                                                                                                                                                                                                                                                                     the, uh, united states and canada are i guess, is, is, going into, uh, some types of agreements to limit, uh, what 's being given  out by power plants,
# 73491:25                                                                                                                                                                                                                                                            and, uh, when i seen some of my friends that  have taken that six week old baby, you know, to someone else , it's just, i can imagine how emotional it must be .
# 164075:14                                                                                                                                                                                                                                                                                                                                                                     so, we got some monster studded snow tires after that.
# 121793:107                                                                                                                                                                                                                                                                             you know, i want to, i want  to throw some charcoal on the grill and, and throw a steak  on there and some baked potatoes and stuff like that
# 53913:6                                                                                                                                                                                                                                                                                                                                                                                  and some kids need  to be spanked  at home.
# 130087:11                                                                                                                                                                                                                                                                                                                                                                          what are some of the things they don't recycle  .
# 15291:54                                                                                                                                                                                                                                                                                                                            it's for, i think, at the same it's for some people to, you know, help them grow in other areas,
# 66765:5                                                                                                                                                                                                                                                                                                                                                                          some of the cases i've heard about  over the years,
# 63606:10                                                                                                                                                                                                                                                                                                                                                                and then some of them are done  in, you know, purely metric.
# 134420:14                                                                                                                                                                                                                                                                                                                                                                  we put up some hummingbird feeders and some bird feeders.
# 74234:44                                                                                                        i think the other thing is that, uh, we have taken some rather drastic turns in our, in our education and the way we approach things  as of maybe starting back when, when i'm number one, you know, and, uh, uh, uh, worrying about self and not, uh, seeing the consequences of the disintegration of the family .
# 105896:51                                                                                                                                                                                                                                                                                                                         and i think it 's good that they're trying  to start some programs down in the elementary schools.
# 171124:6                                                                                                                                                                                                                                                                                                                                                                                        some of that is really bad i think .
# 19728:11                                                                                                                                                                                                                                                                                           where's some reference to this goddamn state of texas and the role that they played  either leading up to  or in  the civil war .
# 129583:26                                                                                                                                                                                                                                                                                                                                                                                 i'm going  to look into some other fields.
# 28711:26                                                                                                                                                                                                                                                                                                                                                     and the guys that, some of the guys that  run this place are very tight
# 110359:35                                                                                                                                                                                                                                                                                                                            like just over the weekend i visited my family, and some cousins i hadn't seen  in a long time,
# 102546:21                                                                                                                                                                                                                                                                                                                                                                                   and i'm not fond of some of those things
# 175724:80                                                                                                                                                                                                                                                                                                               well, i, i, i think we did, i think we did learn some lessons that we weren't, uh, we weren't prepared for ,
# ...
# 168555:17            years    1            year     Y    N
# 53602:9      thunderstorms    1    thunderstorm     Y    N
# 146225:40             glue    1            glue     Y    Y
# 148889:35          insight    1         insight     Y    Y
# 15068:10              ones    1             one     Y    N
# 27799:10            things    1           thing     Y    N
# 13424:44            things    1           thing     Y    N
# 143722:15           people    1          people     Y    Y
# 33859:9             things    1           thing     Y    N
# 156639:7              them    1            they    NF   NF
# 91758:36             light    1           light     Y    Y
# 171693:31           people    1          people     Y    Y
# 73140:10              them    1            they    NF   NF
# 72160:27         exercises    1        exercise     Y    Y
# 135551:31          writers    1          writer     Y    N
# 155436:87             help    1            help     Y    Y
# 31180:170           things    1           thing     Y    N
# 90848:29            places    1           place     Y    N
# 22932:13              ones    1             one     Y    N
# 94526:45            people    1          people     Y    Y
# 127169:7            skirts    1           skirt     Y    Y
# 48532:18          programs    1         program    NF   NF
# 6397:25          negatives    1        negative     Y    N
# 23861:102        scallions    1        scallion     Y    N
# 10895:45            awards    1           award     Y    N
# 91758:53             light    1           light     Y    Y
# 138037:56          respect    1         respect     Y    Y
# 176628:53          benches    1           bench     Y    N
# 95400:23              work    1            work     Y    Y
# 64564:10           weather    1         weather     Y    Y
# 50235:53          channels    1         channel     Y    N
# 142141:14            those    1           those    NF   NF
# 37283:73              ways    1             way     Y    Y
# 43642:11              ones    1             one     Y    N
# 77358:19          shopping    1        shopping     N    Y
# 108972:69         tomatoes    1         tomatoe    NF   NF
# 164404:48        murderers    1        murderer     Y    N
# 100571:7              them    1            they    NF   NF
# 94747:14             shows    1            show     Y    Y
# 146612:75             them    1            they    NF   NF
# 55919:10             folks    1            folk     N    N
# 8930:19               time    1            time     Y    Y
# 147582:28           people    1          people     Y    Y
# 92716:8              times    1            time     Y    Y
# 104230:49            notes    1            note     Y    Y
# 115742:25           things    1           thing     Y    N
# 96261:16             tours    1            tour     Y    Y
# 118309:83           things    1           thing     Y    N
# 83449:32             cases    1            case     Y    Y
# 2767:14           programs    1         program    NF   NF
# 134101:49       litigation    1      litigation     N    Y
# 81929:47        advantages    1       advantage     Y    Y
# 149485:72            least    1           least     N    N
# 13411:17     organizations    1    organization     Y    Y
# 110398:27             work    1            work     Y    Y
# 83198:48             truth    1           truth     Y    Y
# 74301:11          flickers    1         flicker     Y    N
# 9608:21               wire    1            wire     Y    Y
# 160993:10             ones    1             one     Y    N
# 140815:71          classes    1           class     Y    Y
# 31489:41       professions    1      profession     Y    Y
# 43407:11           friends    1          friend     Y    N
# 161619:23          sailing    1         sailing     Y    Y
# 121023:37            areas    1            area     Y    Y
# 113475:14         everyday    1        everyday    NF   NF
# 31254:36             cases    1            case     Y    Y
# 108975:9            yogurt    1          yogurt    NF   NF
# 74324:8             people    1          people     Y    Y
# 129004:16          effects    1          effect     Y    Y
# 55311:27            cities    1            city     Y    N
# 136180:24         highways    1         highway     Y    N
# 31917:13           wreaths    1          wreath     Y    N
# 73173:67            others    1           other    NF   NF
# 142828:81             need    1            need     Y    Y
# 19999:14           history    1         history     Y    Y
# 99236:8           teachers    1         teacher     Y    N
# 14637:17          sections    1         section     Y    Y
# 49551:24          features    1         feature     Y    N
# 16318:47             chips    1            chip     Y    N
# 80333:17             women    1           woman     Y    N
# 90230:11       accomplices    1      accomplice     Y    N
# 156650:7              them    1            they    NF   NF
# 7285:11            afghans    1          afghan     Y    N
# 136539:14           nights    1           night     Y    Y
# 115490:21           things    1           thing     Y    N
# 67466:21         equipment    1       equipment     N    Y
# 73538:38            people    1          people     Y    Y
# 80218:50               sun    1             sun     Y    Y
# 6607:30               guys    1             guy     Y    N
# 2180:39              money    1           money     N    Y
# 138349:36             ways    1             way     Y    Y
# 57069:61            things    1           thing     Y    N
# 167037:72       mechanisms    1       mechanism     Y    Y
# 136110:19           things    1           thing     Y    N
# 37846:61           science    1         science     Y    Y
# 84152:34            plants    1           plant     Y    Y
# 156896:23       statistics    1       statistic     Y    N
# 23994:24        vegetables    1       vegetable     Y    Y
# 105043:10          recipes    1          recipe     Y    N
# 96042:48         instances    1        instance     Y    N
# 126455:10             that    1            that    NF   NF
# 172225:11            games    1            game     Y    Y
# 63417:44            things    1           thing     Y    N
# 137794:5         driveways    1        driveway     Y    N
# 99291:5            coaches    1           coach     Y    Y
# 130514:28          friends    1          friend     Y    N
# 164352:16            cases    1            case     Y    Y
# 56072:31         campaigns    1        campaign     Y    Y
# 119842:10          talkies    1           talky    NF   NF
# 157934:65           issues    1           issue     Y    Y
# 14969:24        experience    1      experience     Y    Y
# 145536:63           people    1          people     Y    Y
# 24962:14            places    1           place     Y    N
# 146198:134        material    1        material     Y    Y
# 123419:8             paper    1           paper     Y    Y
# 120455:28            names    1            name     Y    N
# 92861:25             parts    1            part     Y    Y
# 84205:26              them    1            they    NF   NF
# 27780:99              ways    1             way     Y    Y
# 112989:20           people    1          people     Y    Y
# 134228:135            mums    1             mum     N    N
# 155148:17            goals    1            goal     Y    N
# 77309:26            trends    1           trend     Y    N
# 158550:31        diplomacy    1       diplomacy     N    Y
# 78394:33            things    1           thing     Y    N
# 108182:40           things    1           thing     Y    N
# 168217:7                it    1              it     N    N
# 57861:27            things    1           thing     Y    N
# 88001:41            relief    1          relief     Y    Y
# 149669:184          things    1           thing     Y    N
# 73755:84              ways    1             way     Y    Y
# 113957:66           crimes    1           crime     Y    Y
# 35674:29             money    1           money     N    Y
# 164073:37              ice    1             ice     Y    Y
# 165280:27      experiences    1      experience     Y    Y
# 106437:19            times    1            time     Y    Y
# 14653:39           tickets    1          ticket     Y    Y
# 169898:50       experience    1      experience     Y    Y
# 166634:38            money    1           money     N    Y
# 98932:25            points    1           point     Y    Y
# 6395:54              stuff    1           stuff     Y    Y
# 24421:69        experience    1      experience     Y    Y
# 30438:27             stuff    1           stuff     Y    Y
# 165750:14           driven    1           drive     Y    Y
# 46244:16              have    1            have    NF   NF
# 15261:95            people    1          people     Y    Y
# 89580:13            movies    1           movie     Y    N
# 137317:74            trees    1            tree     Y    N
# 3226:17           examples    1         example     Y    Y
# 94280:31             sauce    1           sauce     Y    Y
# 96724:27           strides    1          stride     Y    N
# 171931:87            chips    1            chip     Y    N
# 48103:10         attention    1       attention     Y    Y
# 38063:54          software    1        software     N    Y
# 29177:102        sternness    1       sternness     N    Y
# 40705:25              time    1            time     Y    Y
# 6414:31                see    1             see     Y    N
# 166085:182           items    1            item     Y    N
# 138155:36            plans    1            plan     Y    N
# 85965:39            things    1           thing     Y    N
# 38581:37            things    1           thing     Y    N
# 27808:28        television    1      television     Y    Y
# 159110:25            these    1           these    NF   NF
# 138174:28            tools    1            tool     Y    N
# 171967:54            cases    1            case     Y    Y
# 53690:14              kids    1             kid     Y    Y
# 25010:18           college    1         college     Y    Y
# 8884:22               both    1            both    NF   NF
# 82021:22          warnings    1         warning     Y    Y
# 138291:137          things    1           thing     Y    N
# 74560:83              help    1            help     Y    Y
# 19161:75               let    1             let     Y    Y
# 106391:27           places    1           place     Y    N
# 24959:32           schools    1          school     Y    Y
# 85193:35          projects    1         project     Y    N
# 121941:10           things    1           thing     Y    N
# 147067:15          schools    1          school     Y    Y
# 143578:37            cases    1            case     Y    Y
# 123812:31            trees    1            tree     Y    N
# 167299:10         property    1        property     Y    Y
# 103701:14       discussion    1      discussion     Y    Y
# 69750:37          reunions    1         reunion     Y    Y
# 121775:50            rolls    1            roll     Y    N
# 24421:47        experience    1      experience     Y    Y
# 83966:23               oil    1             oil     Y    Y
# 157049:37               it    1              it     N    N
# 46132:24             these    1           these    NF   NF
# 37616:97            people    1          people     Y    Y
# 147613:4            people    1          people     Y    Y
# 174455:135        research    1        research     Y    Y
# 7265:10         remodeling    1      remodeling    NF   NF
# 99956:17         relatives    1        relative     Y    N
# 170937:25            cases    1            case     Y    Y
# 8865:67               time    1            time     Y    Y
# 58800:5              stuff    1           stuff     Y    Y
# 116197:36           people    1          people     Y    Y
# 109040:25          friends    1          friend     Y    N
# 74797:57          termites    1         termite     Y    N
# 7091:13             people    1          people     Y    Y
# 148456:26               it    1              it     N    N
# 57651:63            threes    1           three     Y    N
# 7526:63               ones    1             one     Y    N
# 68658:19            people    1          people     Y    Y
# 16570:13            people    1          people     Y    Y
# 8867:13            sconces    1          sconce     Y    N
# 125063:17            cards    1            card     Y    N
# 121793:56         charcoal    1        charcoal     N    Y
# 154774:35           people    1          people     Y    Y
# 87654:69            things    1           thing     Y    N
# 62771:99             music    1           music     N    Y
# 163289:195           money    1           money     N    Y
# 37263:24              both    1            both    NF   NF
# 32953:43          broccoli    1        broccoli     N    Y
# 23634:28             foods    1            food     Y    Y
# 108521:93             them    1            they    NF   NF
# 67780:49           friends    1          friend     Y    N
# 168606:48      programming    1     programming    NF   NF
# 27798:15            things    1           thing     Y    N
# 120747:13        affection    1       affection     Y    Y
# 47856:7               them    1            they    NF   NF
# 114202:81           people    1          people     Y    Y
# 23630:11             foods    1            food     Y    Y
# 87467:20            cheese    1          cheese     Y    Y
# 168976:57            least    1           least     N    N
# 166762:101            life    1            life     Y    Y
# 123797:41         firewood    1        firewood     N    Y
# 63076:40          training    1        training     N    Y
# 54840:11               ads    1              ad     Y    N
# 18547:110        gardenias    1        gardenia     Y    N
# 7017:34             people    1          people     Y    Y
# 65258:45              good    1            good     N    Y
# 15216:13              work    1            work     Y    Y
# 13420:11            things    1           thing     Y    N
# 80877:63              help    1            help     Y    Y
# 38947:33            things    1           thing     Y    N
# 154517:48           people    1          people     Y    Y
# 105338:42           people    1          people     Y    Y
# 36611:16             parks    1            park     Y    N
# 22419:43            people    1          people     Y    Y
# 54865:37              time    1            time     Y    Y
# 171972:37            cases    1            case     Y    Y
# 82503:72          research    1        research     Y    Y
# 170188:22             work    1            work     Y    Y
# 19360:7          countries    1         country     Y    Y
# 77593:15            things    1           thing     Y    N
# 166799:28            homes    1            home     Y    N
# 17008:76            things    1           thing     Y    N
# 118769:33          stories    1           story     Y    N
# 148372:13            songs    1            song     Y    Y
# 83450:9             juries    1            jury     Y    N
# 30439:48            things    1           thing     Y    N
# 46441:47          training    1        training     N    Y
# 9762:24                 it    1              it     N    N
# 163122:31        dumpsters    1        dumpster    NF   NF
# 106565:53   responsibility    1  responsibility     Y    Y
# 154338:10            music    1           music     N    Y
# 138340:30             ones    1             one     Y    N
# 19284:42            change    1          change     Y    Y
# 98822:22              that    1            that    NF   NF
# 18087:40             tapes    1            tape     Y    Y
# 103868:139           cases    1            case     Y    Y
# 130065:25           places    1           place     Y    N

# %%
# For now ignore all the words which are more than one word long

# somedata['NP'] = somedata['Item'].apply(lambda x: uniq.loc[x, 'NP'])
somedata['len'] = somedata['NP'].apply(lambda x: len(x.split()))
somedata = somedata[somedata['len']==1]
somedata['Count'] = somedata['Item'].apply(lambda x: uniq.loc[x, 'Count'])
somedata['Mass'] = somedata['Item'].apply(lambda x: uniq.loc[x, 'Mass'])
# somedata = somedata[(somedata['Count']!='NF')|(somedata['Mass']!='NF')]

# %%
repl = {'Y':'yes', 'N':'no'}
somedata = somedata.replace({"Count":repl, "Mass":repl})

# %%
somedata['Lemma'] = somedata['Item'].apply(lambda x: uniq.loc[x, 'lemma'])
somedata.to_csv('corpus_some-master/masscount.tsv', sep='\t', index=False)

# %%
Counter(somedata['Mass'])
# Out:
# Counter({'yes': 6800, 'no': 4530, 'NF': 1580})

# %%
Counter(somedata['Count'])
# Out:
# Counter({'yes': 9970, 'NF': 1580, 'no': 1360})

# %%
somedata.shape
# Out:
# (12910, 16)

# %%
somedata['Lemma'].unique().shape
# Out:
# (509,)

# %%
somedata[(somedata['Mass']=='yes') & (somedata['Count']=='no')]['Lemma'].unique()
# Out:
# array(['information', 'money', 'equipment', 'skating', 'music',
#        'interference', 'harassment', 'charcoal', 'esteem', 'good', 'golf',
#        'compassion', 'credence', 'cooking', 'independence', 'relevance',
#        'little', 'latitude', 'steel', 'ooze', 'furniture', 'butter',
#        'knowledge', 'wealth', 'broccoli', 'sewing', 'peace', 'sternness',
#        'feedback', 'mayonnaise', 'gardening', 'expertise', 'cocaine',
#        'continuity', 'data', 'hardware', 'wallpaper', 'discrimination',
#        'loam', 'suspense', 'marketing', 'news', 'stability', 'socialism',
#        'shopping', 'litigation', 'diplomacy', 'software', 'firewood',
#        'training'], dtype=object)

# %%
somedata[somedata['Lemma']=='continuity']
# Out:
#           Item  workerid  Rating Partitive  StrengthSome Mention Subjecthood  \
# 8500  77906:47        99       1        no           5.4     new       other
# 8501  77906:47       170       2        no           5.4     new       other
# 8502  77906:47       115       2        no           5.4     new       other
# 8503  77906:47       103       2        no           5.4     new       other
# 8504  77906:47       187       1        no           5.4     new       other
# 8505  77906:47       148       2        no           5.4     new       other
# 8506  77906:47       240       1        no           5.4     new       other
# 8507  77906:47        78       2        no           5.4     new       other
# 8508  77906:47       131       1        no           5.4     new       other
# 8509  77906:47       191       3        no           5.4     new       other
#
#      Modification  \
# 8500   unmodified
# 8501   unmodified
# 8502   unmodified
# 8503   unmodified
# 8504   unmodified
# 8505   unmodified
# 8506   unmodified
# 8507   unmodified
# 8508   unmodified
# 8509   unmodified
#
#                                                          Sentence  \
# 8500  but, uh, i-, it seems that there should be some continuity,
# 8501  but, uh, i-, it seems that there should be some continuity,
# 8502  but, uh, i-, it seems that there should be some continuity,
# 8503  but, uh, i-, it seems that there should be some continuity,
# 8504  but, uh, i-, it seems that there should be some continuity,
# 8505  but, uh, i-, it seems that there should be some continuity,
# 8506  but, uh, i-, it seems that there should be some continuity,
# 8507  but, uh, i-, it seems that there should be some continuity,
# 8508  but, uh, i-, it seems that there should be some continuity,
# 8509  but, uh, i-, it seems that there should be some continuity,
#
#       SentenceLength  Trial          NP  len Count Mass       Lemma
# 8500              11     20  continuity    1    no  yes  continuity
# 8501              11     20  continuity    1    no  yes  continuity
# 8502              11     20  continuity    1    no  yes  continuity
# 8503              11     20  continuity    1    no  yes  continuity
# 8504              11     20  continuity    1    no  yes  continuity
# 8505              11     20  continuity    1    no  yes  continuity
# 8506              11     20  continuity    1    no  yes  continuity
# 8507              11     20  continuity    1    no  yes  continuity
# 8508              11     20  continuity    1    no  yes  continuity
# 8509              11     20  continuity    1    no  yes  continuity

# %%
somedata[somedata['Item']=='154338:10']['Rating'].mean()
# Out:
# 6.9

# %% [markdown]
# 79557:42
# 148561:14
# 33466:11
# 89238:15
